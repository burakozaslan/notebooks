# %% [markdown]
# #Welcome my first notebook project

# %% [markdown]
# **Burak Özaslan** Business Analyst

# %% [markdown]
# *I am interested in data science because i am planning to improve myself and maybe career shift soon*

# %% [markdown]
# ###My code will show results of 2+2

# %%
2+2
# Out:
# 4

# %% [markdown]
# 1. My first ordered list item
# 2. Second item
# ⋅⋅* my first sub-list.
# ⋅⋅* my second sub-list.
#
# [This is a link](https://www.coursera.org/in-progress)
#
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "My logo title")
